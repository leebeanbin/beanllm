# %% [markdown]
# # 📦 beanllm 설치 및 환경 설정 가이드
#
# 이 노트북은 beanllm을 처음 사용하는 사용자를 위한 완전한 설치 및 환경 설정 가이드를 제공합니다.
#
# ## 📋 목차
#
# - [1. 패키지 설치](#1-패키지-설치)
# - [2. 환경 변수 설정](#2-환경-변수-설정)
# - [3. 의존성 확인](#3-의존성-확인)
# - [4. 기본 테스트](#4-기본-테스트)
# - [5. 다음 단계](#5-다음-단계)
#
# ---
#
# ## 🎯 학습 목표
#
# 이 노트북을 완료하면:
# - ✅ beanllm 패키지를 올바르게 설치할 수 있습니다
# - ✅ 필요한 환경 변수를 설정할 수 있습니다
# - ✅ 설치가 제대로 되었는지 확인할 수 있습니다
# - ✅ 기본적인 사용법을 이해할 수 있습니다

# %% [markdown]
# ## 1. 패키지 설치
#
# beanllm은 다양한 설치 옵션을 제공합니다. 사용 목적에 따라 적절한 설치 방법을 선택할 수 있습니다.
#
# ### 1.1 기본 설치
#
# 가장 간단한 방법은 pip를 사용하는 것입니다. 이 방법은 최소한의 기능만 설치하므로, 필요한 Provider SDK는 별도로 설치해야 합니다.
#
# > 💡 **언제 사용하나요?**
# > - 처음 시작하는 경우
# > - 특정 Provider만 사용할 계획인 경우
# > - 디스크 공간이 제한적인 경우

# %%
# ============================================
# 기본 설치 (최소 기능만)
# ============================================

# 기본 설치 명령어
# !pip install beanllm

print("=" * 60)
print("기본 설치")
print("=" * 60)
print("\n✅ 설치 명령어:")
print("  !pip install beanllm")
print("\n📦 포함되는 내용:")
print("  - beanllm 코어 패키지")
print("  - 기본 유틸리티 및 도메인 로직")
print("  - 문서 처리 기본 기능")
print("  - 벡터 스토어 기본 지원")
print("\n❌ 포함되지 않는 내용:")
print("  - LLM Provider SDK (OpenAI, Anthropic 등)")
print("  - ML 기능 (Vision, Audio 등)")
print("  - 분산 아키텍처 (Redis, Kafka)")
print("\n💡 다음 단계:")
print("  - 필요한 Provider SDK를 별도로 설치:")
print("    !pip install openai          # OpenAI 사용 시")
print("    !pip install anthropic       # Anthropic 사용 시")
print("    !pip install google-generativeai  # Google Gemini 사용 시")

# 실제 설치 예제 (주석 해제하여 실행)
# import subprocess
# import sys
#
# def install_package(package):
#     """패키지 설치 헬퍼 함수"""
#     subprocess.check_call([sys.executable, "-m", "pip", "install", package])
#     print(f"✅ {package} 설치 완료!")
#
# # 기본 설치
# print("\n[1단계] beanllm 기본 설치...")
# install_package("beanllm")
#
# # Provider SDK 설치 예제
# print("\n[2단계] Provider SDK 설치 (선택적)...")
# # install_package("openai")
# # install_package("anthropic")
# # install_package("google-generativeai")

# %% [markdown]
# ### 1.2 Provider별 설치
#
# 특정 Provider만 사용하려면 해당 Provider의 extra를 포함하여 설치할 수 있습니다. 이 방법은 필요한 Provider만 설치하므로 디스크 공간을 절약할 수 있습니다.
#
# > 💡 **언제 사용하나요?**
# > - 특정 Provider만 사용할 계획인 경우
# > - 디스크 공간이 제한적인 경우
# > - 프로덕션 환경에서 최소한의 의존성만 원하는 경우
#
# > ⚠️ **주의사항**: 여러 Provider를 사용하려면 각각 별도로 설치하거나 `[all]` 옵션을 사용하세요.

# %%
# ============================================
# Provider별 설치
# ============================================

print("=" * 60)
print("Provider별 설치 옵션")
print("=" * 60)

# 각 Provider별 설치 명령어
providers = {
    "openai": {
        "command": "!pip install beanllm[openai]",
        "description": "OpenAI SDK 포함 (GPT-4, GPT-3.5 등)",
        "includes": ["openai", "tiktoken"],
        "use_case": "OpenAI 모델만 사용하는 경우",
    },
    "anthropic": {
        "command": "!pip install beanllm[anthropic]",
        "description": "Anthropic SDK 포함 (Claude Sonnet, Opus 등)",
        "includes": ["anthropic"],
        "use_case": "Claude 모델만 사용하는 경우",
    },
    "gemini": {
        "command": "!pip install beanllm[gemini]",
        "description": "Google Gemini SDK 포함 (Gemini Pro, Flash 등)",
        "includes": ["google-generativeai"],
        "use_case": "Google Gemini 모델만 사용하는 경우",
    },
    "deepseek": {
        "command": "!pip install beanllm[deepseek]",
        "description": "DeepSeek SDK 포함",
        "includes": ["openai"],  # DeepSeek은 OpenAI 호환 API 사용
        "use_case": "DeepSeek 모델만 사용하는 경우",
    },
    "perplexity": {
        "command": "!pip install beanllm[perplexity]",
        "description": "Perplexity SDK 포함",
        "includes": ["openai"],  # Perplexity는 OpenAI 호환 API 사용
        "use_case": "Perplexity 모델만 사용하는 경우",
    },
    "ollama": {
        "command": "!pip install beanllm[ollama]",
        "description": "Ollama 클라이언트 포함 (로컬 LLM)",
        "includes": ["ollama"],
        "use_case": "로컬에서 Ollama를 실행하는 경우",
    },
}

print("\n📦 지원하는 Provider:")
for provider, info in providers.items():
    print(f"\n[{provider.upper()}]")
    print(f"  명령어: {info['command']}")
    print(f"  설명: {info['description']}")
    print(f"  포함 패키지: {', '.join(info['includes'])}")
    print(f"  사용 사례: {info['use_case']}")

# 실제 설치 예제 (주석 해제하여 실행)
# print("\n" + "=" * 60)
# print("실제 설치 예제")
# print("=" * 60)
#
# # 예: OpenAI만 설치
# # !pip install beanllm[openai]
#
# # 예: 여러 Provider 동시 설치
# # !pip install beanllm[openai,anthropic,gemini]
#
# print("\n💡 여러 Provider 동시 설치:")
# print("  !pip install beanllm[openai,anthropic,gemini]")
# print("  위 명령어는 OpenAI, Anthropic, Google Gemini를 모두 설치합니다.")

print("\n" + "=" * 60)
print("✅ Provider별 설치 옵션 확인 완료!")
print("=" * 60)

# %% [markdown]
# ### 1.3 전체 설치 (권장)
#
# 모든 Provider와 기능을 사용하려면 `[all]` 옵션을 사용하세요. 이 방법은 모든 기능을 한 번에 설치하므로 가장 편리합니다.
#
# > 💡 **언제 사용하나요?**
# > - 모든 기능을 사용할 계획인 경우
# > - 개발 환경에서 다양한 Provider를 테스트하는 경우
# > - 디스크 공간이 충분한 경우
#
# > ⚠️ **주의사항**: 전체 설치에는 많은 패키지가 포함되므로 설치 시간이 오래 걸릴 수 있습니다.

# %%
# ============================================
# 전체 설치 (권장)
# ============================================

print("=" * 60)
print("전체 설치 (권장)")
print("=" * 60)

# 전체 설치 명령어
# !pip install beanllm[all]

print("\n✅ 설치 명령어:")
print("  !pip install beanllm[all]")

print("\n📦 포함되는 모든 패키지:")
print("\n[LLM Provider SDK]")
print("  - openai: OpenAI SDK (GPT-4, GPT-3.5 등)")
print("  - anthropic: Anthropic SDK (Claude Sonnet, Opus 등)")
print("  - google-generativeai: Google Gemini SDK")
print("  - ollama: Ollama 클라이언트 (로컬 LLM)")

print("\n[ML 기능]")
print("  - pdfplumber: PDF 처리")
print("  - pillow: 이미지 처리")
print("  - opencv-python: 컴퓨터 비전")
print("  - transformers: HuggingFace 모델")
print("  - torch: PyTorch (선택적)")

print("\n[벡터 스토어]")
print("  - chromadb: ChromaDB 클라이언트")
print("  - faiss-cpu: FAISS (로컬 벡터 검색)")
print("  - qdrant-client: Qdrant 클라이언트")
print("  - pinecone-client: Pinecone 클라이언트")
print("  - weaviate-client: Weaviate 클라이언트")

print("\n[기타 필수 의존성]")
print("  - numpy: 수치 계산")
print("  - pandas: 데이터 처리")
print("  - requests: HTTP 클라이언트")
print("  - python-dotenv: 환경 변수 관리")
print("  - pydantic: 데이터 검증")

print("\n⏱️ 예상 설치 시간:")
print("  - 일반적인 인터넷 속도: 5-10분")
print("  - 느린 인터넷 속도: 15-20분")

print("\n💡 설치 확인:")
print("  설치 후 다음 명령어로 확인:")
print("  python -c 'import beanllm; print(beanllm.__version__)'")

# 실제 설치 예제 (주석 해제하여 실행)
# import subprocess
# import sys
#
# print("\n" + "=" * 60)
# print("실제 설치 진행...")
# print("=" * 60)
#
# try:
#     subprocess.check_call([
#         sys.executable, "-m", "pip", "install", "beanllm[all]"
#     ])
#     print("\n✅ 전체 설치 완료!")
# except subprocess.CalledProcessError as e:
#     print(f"\n❌ 설치 실패: {e}")
#     print("💡 네트워크 연결을 확인하거나 개별 Provider를 설치해보세요.")

print("\n" + "=" * 60)
print("✅ 전체 설치 정보 확인 완료!")
print("=" * 60)

# %% [markdown]
# ### 1.4 분산 아키텍처 설치
#
# Redis와 Kafka를 사용한 분산 아키텍처를 사용하려면:

# %%
# 분산 아키텍처 포함
# !pip install beanllm[distributed]

# 또는 전체 + 분산
# !pip install beanllm[all,distributed]

print("✅ 분산 아키텍처 설치:")
print("!pip install beanllm[distributed]")
print("\n포함되는 패키지:")
print("- redis: 분산 Rate Limiting, Caching, Locks")
print("- kafka-python: 이벤트 스트리밍, 작업 큐")
print("\n⚠️ 주의: Redis와 Kafka 서버가 별도로 실행되어야 합니다.")

# %% [markdown]
# ### 1.5 개발 모드 설치
#
# 코드를 수정하거나 개발에 참여하려면 개발 모드로 설치하세요.

# %%
# 개발 모드 설치 (소스 코드 수정 가능)
# git clone https://github.com/leebeanbin/beanllm.git
# cd beanllm
# pip install -e ".[dev,all]"

# 또는 Poetry 사용 (권장)
# poetry install --extras all
# poetry shell

print("✅ 개발 모드 설치:")
print("1. Git 저장소 클론")
print("2. pip install -e '.[dev,all]' 또는 poetry install")
print("\n포함되는 개발 도구:")
print("- pytest: 테스트 프레임워크")
print("- ruff: 코드 포맷팅 및 린팅")
print("- mypy: 타입 체킹")
print("- black: 코드 포맷팅 (선택적)")

# %% [markdown]
# ## 2. 환경 변수 설정
#
# beanllm은 환경 변수를 통해 API 키와 설정을 관리합니다. 이는 보안상 중요한 정보를 코드에 하드코딩하지 않고 안전하게 관리할 수 있게 해줍니다.
#
# ### 2.1 .env 파일 생성
#
# 프로젝트 루트에 `.env` 파일을 생성하여 API 키를 설정합니다. `python-dotenv` 패키지가 자동으로 이 파일을 로드합니다.
#
# > 💡 **팁**: `.env` 파일은 Git에 커밋하지 마세요! `.gitignore`에 추가되어 있습니다.
#
# > ⚠️ **보안 주의사항**:
# > - `.env` 파일을 절대 Git에 커밋하지 마세요
# > - API 키를 코드에 직접 작성하지 마세요
# > - 프로덕션 환경에서는 환경 변수 관리 시스템을 사용하세요

# %%
import os
from pathlib import Path

# ============================================
# .env 파일 생성 및 설정
# ============================================

print("=" * 60)
print(".env 파일 설정")
print("=" * 60)

# .env 파일 내용 (상세한 템플릿)
env_template = """# ============================================
# LLM Provider API Keys
# ============================================
# 각 Provider의 API 키를 설정하세요.
# 사용하지 않는 Provider는 주석 처리하거나 비워둘 수 있습니다.

# OpenAI (GPT-4, GPT-3.5 등)
# API 키 발급: https://platform.openai.com/api-keys
OPENAI_API_KEY=sk-your-openai-key-here

# Anthropic (Claude Sonnet, Opus 등)
# API 키 발급: https://console.anthropic.com/
ANTHROPIC_API_KEY=sk-ant-your-anthropic-key-here

# Google Gemini (Gemini Pro, Flash 등)
# API 키 발급: https://makersuite.google.com/app/apikey
GEMINI_API_KEY=your-gemini-key-here

# DeepSeek
# API 키 발급: https://platform.deepseek.com/
DEEPSEEK_API_KEY=sk-your-deepseek-key-here

# Perplexity
# API 키 발급: https://www.perplexity.ai/settings/api
PERPLEXITY_API_KEY=pplx-your-perplexity-key-here

# ============================================
# 로컬 LLM (Ollama)
# ============================================
# Ollama는 로컬에서 실행되므로 API 키가 필요 없습니다.
# Ollama 서버 주소만 설정하면 됩니다.
OLLAMA_HOST=http://localhost:11434

# ============================================
# 분산 아키텍처 (선택적)
# ============================================
# Redis와 Kafka를 사용한 분산 아키텍처를 활성화하려면
# USE_DISTRIBUTED=true로 설정하고 Redis/Kafka 서버 정보를 입력하세요.

USE_DISTRIBUTED=false
REDIS_HOST=localhost
REDIS_PORT=6379
REDIS_PASSWORD=  # 비밀번호가 있는 경우
REDIS_DB=0

KAFKA_BOOTSTRAP_SERVERS=localhost:9092
KAFKA_SECURITY_PROTOCOL=PLAINTEXT  # SASL_PLAINTEXT, SASL_SSL 등

# ============================================
# 기타 설정 (선택적)
# ============================================
# 로깅 레벨 (DEBUG, INFO, WARNING, ERROR)
LOG_LEVEL=INFO

# 기본 모델 (설정하지 않으면 자동 선택)
# DEFAULT_MODEL=gpt-4o
"""

print("\n📝 .env 파일 템플릿:")
print(env_template)


# .env 파일 생성 함수
def create_env_file():
    """.env 파일 생성 헬퍼 함수"""
    env_path = Path(".env")

    if env_path.exists():
        print(f"\n⚠️ .env 파일이 이미 존재합니다: {env_path.absolute()}")
        print("   기존 파일을 덮어쓰지 않습니다.")
        print("   수동으로 편집하거나 백업 후 삭제하세요.")
        return False

    try:
        with open(env_path, "w", encoding="utf-8") as f:
            f.write(env_template)
        print(f"\n✅ .env 파일이 생성되었습니다: {env_path.absolute()}")
        print("   이제 각 Provider의 API 키를 실제 값으로 교체하세요.")
        return True
    except Exception as e:
        print(f"\n❌ .env 파일 생성 실패: {e}")
        return False


# .env 파일 생성 (주석 해제하여 실행)
# create_env_file()

print("\n💡 .env 파일 사용 방법:")
print("=" * 60)
print("1. 프로젝트 루트에 .env 파일 생성")
print("2. 위의 템플릿을 복사하여 .env 파일에 붙여넣기")
print("3. 각 Provider의 API 키를 실제 값으로 교체")
print("4. python-dotenv가 자동으로 로드합니다")
print("\n📚 API 키 발급 링크:")
print("  - OpenAI: https://platform.openai.com/api-keys")
print("  - Anthropic: https://console.anthropic.com/")
print("  - Google Gemini: https://makersuite.google.com/app/apikey")
print("  - DeepSeek: https://platform.deepseek.com/")
print("  - Perplexity: https://www.perplexity.ai/settings/api")

print("\n⚠️ 보안 주의사항:")
print("  - .env 파일을 절대 Git에 커밋하지 마세요")
print("  - API 키를 코드에 직접 작성하지 마세요")
print("  - 프로덕션 환경에서는 환경 변수 관리 시스템 사용 권장")

print("\n" + "=" * 60)
print("✅ .env 파일 설정 정보 확인 완료!")
print("=" * 60)

# %% [markdown]
# ### 2.3 환경 변수 확인
#
# 설정한 환경 변수가 제대로 로드되었는지 확인합니다. 이는 API 키가 올바르게 설정되었는지 확인하는 중요한 단계입니다.
#
# > 💡 **팁**: 환경 변수가 로드되지 않으면 API 호출이 실패합니다. 반드시 확인하세요!

# %%
from beanllm.utils import EnvConfig
import os

# ============================================
# 환경 변수 확인
# ============================================

print("=" * 60)
print("환경 변수 확인")
print("=" * 60)

# 환경 변수 로드 확인
try:
    config = EnvConfig()
    print("\n✅ EnvConfig 로드 성공!")
except Exception as e:
    print(f"\n❌ EnvConfig 로드 실패: {e}")
    print("💡 .env 파일이 올바른 위치에 있는지 확인하세요.")
    config = None

if config:
    print("\n🔍 LLM Provider API 키 확인:")
    print("-" * 60)

    providers_status = {
        "OpenAI": ("openai_api_key", "GPT-4, GPT-3.5 등"),
        "Anthropic": ("anthropic_api_key", "Claude Sonnet, Opus 등"),
        "Google Gemini": ("gemini_api_key", "Gemini Pro, Flash 등"),
        "DeepSeek": ("deepseek_api_key", "DeepSeek 모델"),
        "Perplexity": ("perplexity_api_key", "Perplexity 모델"),
    }

    for provider_name, (attr_name, description) in providers_status.items():
        api_key = getattr(config, attr_name, None)
        status = "✅ 설정됨" if api_key and api_key.startswith(("sk-", "pplx-")) else "❌ 미설정"
        masked_key = f"{api_key[:10]}..." if api_key and len(api_key) > 10 else "없음"
        print(f"  {provider_name:20} {status:15} ({description})")
        if api_key:
            print(f"    키: {masked_key}")

    # Ollama 설정 확인
    ollama_host = getattr(config, "ollama_host", None) or os.getenv(
        "OLLAMA_HOST", "http://localhost:11434"
    )
    print(f"\n🖥️  Ollama (로컬 LLM):")
    print(f"  Host: {ollama_host}")
    print(f"  상태: {'✅ 설정됨' if ollama_host else '❌ 미설정'}")

    # 분산 아키텍처 설정 확인
    print("\n📊 분산 아키텍처 설정:")
    print("-" * 60)
    use_distributed = os.getenv("USE_DISTRIBUTED", "false").lower() == "true"
    print(f"  활성화: {'✅ 활성화' if use_distributed else '❌ 비활성화 (인메모리)'}")

    if use_distributed:
        print(f"  Redis Host: {os.getenv('REDIS_HOST', 'localhost')}")
        print(f"  Redis Port: {os.getenv('REDIS_PORT', '6379')}")
        redis_password = os.getenv("REDIS_PASSWORD", "")
        print(f"  Redis Password: {'✅ 설정됨' if redis_password else '❌ 미설정'}")
        print(f"  Kafka Servers: {os.getenv('KAFKA_BOOTSTRAP_SERVERS', 'localhost:9092')}")
    else:
        print("  💡 분산 아키텍처를 사용하려면 USE_DISTRIBUTED=true로 설정하세요.")

    # 설정 요약
    configured_providers = sum(
        1 for _, (attr_name, _) in providers_status.items() if getattr(config, attr_name, None)
    )
    print(f"\n📈 설정 요약:")
    print(f"  - 설정된 Provider: {configured_providers}/{len(providers_status)}개")
    print(f"  - 분산 아키텍처: {'활성화' if use_distributed else '비활성화'}")

    if configured_providers == 0:
        print("\n⚠️ 경고: API 키가 하나도 설정되지 않았습니다!")
        print("   .env 파일에 최소 하나의 Provider API 키를 설정하세요.")

# 환경 변수 직접 확인 (대안 방법)
print("\n" + "=" * 60)
print("환경 변수 직접 확인 (대안 방법)")
print("=" * 60)
print("\n💡 os.getenv()를 사용한 직접 확인:")
print("  import os")
print("  api_key = os.getenv('OPENAI_API_KEY')")
print("  if api_key:")
print("      print('✅ OpenAI API 키 설정됨')")
print("  else:")
print("      print('❌ OpenAI API 키 미설정')")

print("\n" + "=" * 60)
print("✅ 환경 변수 확인 완료!")
print("=" * 60)

# %% [markdown]
# ## 3. 의존성 확인
#
# 설치된 패키지와 버전을 확인합니다.

# %%
import sys

# Python 버전 확인
print(f"🐍 Python 버전: {sys.version}")

# beanllm 버전 확인
try:
    import beanllm

    print(f"✅ beanllm 버전: {beanllm.__version__}")
except ImportError:
    print("❌ beanllm이 설치되지 않았습니다!")
except AttributeError:
    print("✅ beanllm 설치됨 (버전 정보 없음)")

# 주요 의존성 확인
dependencies = {
    "openai": "OpenAI SDK",
    "anthropic": "Anthropic SDK",
    "google.generativeai": "Google Gemini SDK",
    "ollama": "Ollama 클라이언트",
    "redis": "Redis 클라이언트 (분산 아키텍처)",
    "kafka": "Kafka 클라이언트 (분산 아키텍처)",
}

print("\n📦 주요 의존성 확인:")
for module, name in dependencies.items():
    try:
        mod = __import__(module)
        version = getattr(mod, "__version__", "버전 정보 없음")
        print(f"  ✅ {name}: {version}")
    except ImportError:
        print(f"  ❌ {name}: 미설치")

# %% [markdown]
# ## 4. 기본 테스트
#
# 설치가 제대로 되었는지 간단한 테스트를 실행합니다.

# %%
# Import 테스트
try:
    from beanllm import Client, RAGChain, Agent

    print("✅ 핵심 모듈 Import 성공!")
except ImportError as e:
    print(f"❌ Import 실패: {e}")

# Model Registry 테스트
try:
    from beanllm import get_model_registry

    registry = get_model_registry()
    print("✅ Model Registry 생성 성공!")

    # 사용 가능한 모델 확인
    models = registry.get_all_models()
    print(f"📊 사용 가능한 모델 수: {len(models)}")

    # Provider별 모델 수
    by_provider = registry.get_models_by_provider()
    print("\n📋 Provider별 모델 수:")
    for provider, provider_models in by_provider.items():
        print(f"  - {provider}: {len(provider_models)}개")

except Exception as e:
    print(f"❌ Model Registry 테스트 실패: {e}")

# %% [markdown]
# ### 4.1 간단한 Client 테스트
#
# 실제 API 호출을 테스트합니다 (API 키가 설정되어 있어야 합니다).

# %%
import asyncio
from beanllm import Client


async def test_client():
    """Client 기본 테스트"""
    try:
        # Client 생성 (자동으로 사용 가능한 Provider 선택)
        client = Client(model="gpt-4o")

        # 간단한 채팅 테스트
        response = await client.chat(
            messages=[{"role": "user", "content": "안녕하세요! 간단히 인사해주세요."}]
        )

        print("✅ Client 테스트 성공!")
        print(f"📝 응답: {response.content[:100]}...")
        return True
    except Exception as e:
        print(f"❌ Client 테스트 실패: {e}")
        print("\n💡 가능한 원인:")
        print("  - API 키가 설정되지 않았습니다")
        print("  - 네트워크 연결 문제")
        print("  - Provider SDK가 설치되지 않았습니다")
        return False


# 테스트 실행 (주석 해제하여 실행)
# result = await test_client()
print("💡 위의 주석을 해제하여 실제 테스트를 실행하세요.")

# %% [markdown]
# ## 5. 다음 단계
#
# 설치가 완료되었습니다! 다음 튜토리얼로 진행하세요:
#
# ### 📚 추천 학습 순서
#
# 1. **[02_core_client.ipynb](02_core_client.ipynb)** - Client 기본 사용법
#    - LLM Provider 전환
#    - 스트리밍 응답
#    - 파라미터 조정
#
# 2. **[03_rag_and_documents.ipynb](03_rag_and_documents.ipynb)** - RAG 및 문서 처리
#    - 문서 로딩
#    - RAGChain 사용
#    - 텍스트 분할
#
# 3. **[04_embeddings_vector_stores.ipynb](04_embeddings_vector_stores.ipynb)** - 임베딩 및 벡터 스토어
#    - 임베딩 생성
#    - 벡터 스토어 사용
#    - 유사도 검색
#
# ### 🔗 관련 문서
#
# - [README.md](../../README.md) - 프로젝트 개요
# - [QUICK_START.md](../../QUICK_START.md) - 빠른 시작 가이드
# - [API Reference](../API_REFERENCE.md) - 완전한 API 문서
#
# ---
#
# **✅ 설치 완료! 다음 노트북으로 진행하세요.**
